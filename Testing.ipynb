# %%
import numpy as np
import itertools as iter
import pandas as pd
import sklearn.metrics as sklm
import music21 as m21

from pcsPy import *

# %%
a,b,c,d = pcsNetwork(7,7,1)

# %%
a
# Out:
#               pcs  interval                           name
# class
# 7-1     [0123456]  [654321]          chromatic heptamirror
# 7-2Z    [0123457]  [554331]
# 7-3Z    [0123458]  [544431]
# 7-4Z    [0123467]  [544332]
# 7-5Z    [0123468]  [453432]
# 7-6Z    [0123469]  [445332]
# 7-7Z    [0123478]  [533442]
# 7-8Z    [0123479]  [444342]
# 7-9Z    [0123567]  [543342]
# 7-10Z   [0123568]  [444342]
# 7-11Z   [0123569]  [435432]           Debussy's heptatonic
# 7-12Z   [0123578]  [443352]
# 7-13Z   [0123579]  [353442]
# 7-14Z   [0123678]  [532353]
# 7-15Z   [0123679]  [434343]
# 7-16Z   [0123689]  [434343]
# 7-17Z   [0124567]  [543342]
# 7-18Z   [0124568]  [443532]
# 7-19Z   [0124569]  [434541]
# 7-20Z   [0124578]  [434442]
# 7-21Z   [0124579]  [344451]
# 7-22Z   [0124589]  [424641]
# 7-23    [0124678]  [442443]
# 7-24Z   [0124679]  [344352]
# 7-25Z   [0124689]  [343542]          Neapolitan-minor mode
# 7-26   [01246810]  [262623]          Neapolitan-major mode
# ...

# %%
b.loc['[01356810]']
# Out:
# class              7-43
# interval       [254361]
# name        major scale
# Name: [01356810], dtype: object

# %%
p = PCSet(np.array([0,2,4,6,7,9,11]))

# %%
p.LISVector()
# Out:
# array([2, 2, 2, 1, 2, 2, 1])

# %%
p.pcs = p.primeForm()

# %%
p.LISVector()
# Out:
# array([1, 2, 2, 1, 2, 2, 2])
