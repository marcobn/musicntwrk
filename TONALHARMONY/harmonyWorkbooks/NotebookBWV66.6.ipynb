# %% [markdown]
# ### Workbook of tonal harmony
# #### Analysis of the chorale BWV66.6 from the JS Bach's corpus in music21

# %%
from pcsPy import *
import pickle, copy
from IPython.display import Image
# Out:
# <div id="glowscript" class="glowscript"></div>

# %% [markdown]
# Here we import the tonal model we are going to use for the analysis. A tonal model is the matrix of all the operators that connect the chords of a chord library as roman numerals.
# Typical models are built using combinations of basic chord symbols and possible extension.
#
# Use tonalHarmonyModel.py to generate or modify models

# %%
f = open('../tonal.harmony.minimal','rb')
head = pickle.load(f)
table = pickle.load(f)
f.close()
tab = np.array(table)

# %%
head,tab
# Out:
# (['i',
#   'ii',
#   'biii',
#   'iii',
#   'iv',
#   'v',
#   'vi',
#   'bvii',
#   'vii',
#   'I',
#   'bII',
#   'II',
#   'bIII',
#   'III',
#   'IV',
#   'V',
#   'VI',
#   'bVI',
#   'bVII',
#   'VII',
#   'io',
#   'io7',
#   'i/o7',
#   'iio',
#   'iio7',
#   'ii/o7',
#   'biiio',
#   'biiio7',
#   'biii/o7',
#   'iiio',
#   'iiio7',
#   'iii/o7',
#   'ivo',
#   'ivo7',
#   'iv/o7',
#   'vo',
#   'vo7',
#   'v/o7',
#   'vio',
#   'vio7',
#   'vi/o7',
#   'bviio',
#   'bviio7',
#   'bvii/o7',
#   'viio',
#   'viio7',
#   'vii/o7',
#   'i532',
#   'i7',
#   'ib7',
#   'i#7',
#   'i743',
#   'i7#43',
#   'ii532',
#   'ii7',
#   'iib7',
#   'ii#7',
#   'ii743',
#   'ii7#43',
#   'biii532',
#   'biii7',
#   'biiib7',
#   'biii#7',
#   'biii743',
#   'biii7#43',
#   'iii532',
#   'iii7',
#   'iiib7',
#   'iii#7',
#   'iii743',
#   'iii7#43',
#   'iv532',
#   'iv7',
#   'ivb7',
#   'iv#7',
#   'iv743',
#   'iv7#43',
#   'v532',
#   'v7',
#   'vb7',
#   'v#7',
#   'v743',
#   'v7#43',
#   'vi532',
#   'vi7',
#   'vib7',
#   'vi#7',
#   'vi743',
#   'vi7#43',
#   'bvii532',
#   'bvii7',
#   'bviib7',
#   'bvii#7',
#   'bvii743',
#   'bvii7#43',
#   'vii532',
#   'vii7',
#   'viib7',
#   'vii#7',
#   'vii743',
#   'vii7#43',
#   'I532',
#   'I7',
#   'Ib7',
#   'I#7',
#   'I743',
#   'I7#43',
#   'bII532',
#   'bII7',
#   'bIIb7',
#   'bII#7',
#   'bII743',
#   'bII7#43',
#   'II532',
#   'II7',
#   'IIb7',
#   'II#7',
#   'II743',
#   'II7#43',
#   'bIII532',
#   'bIII7',
#   'bIIIb7',
#   'bIII#7',
#   'bIII743',
#   'bIII7#43',
#   'III532',
#   'III7',
#   'IIIb7',
#   'III#7',
#   'III743',
#   'III7#43',
#   'IV532',
#   'IV7',
#   'IVb7',
#   'IV#7',
#   'IV743',
#   'IV7#43',
#   'V532',
#   'V7',
#   'Vb7',
#   'V#7',
#   'V743',
#   'V7#43',
#   'VI532',
#   'VI7',
#   'VIb7',
#   'VI#7',
#   'VI743',
#   'VI7#43',
#   'bVI532',
#   'bVI7',
#   'bVIb7',
#   'bVI#7',
#   'bVI743',
#   'bVI7#43',
#   'bVII532',
#   'bVII7',
#   'bVIIb7',
#   'bVII#7',
#   'bVII743',
#   'bVII7#43',
#   'VII532',
#   'VII7',
#   'VIIb7',
#   'VII#7',
#   'VII743',
#   'VII7#43',
#   'i52',
#   'ii52',
#   'biii52',
#   'iii52',
#   'iv52',
#   'v52',
#   'vi52',
#   'bvii52',
#   'vii52',
#   'i[no5]',
#   'i7[no5]',
#   'i7[no5][no1]',
#   'i9[no5]',
#   'i9[no3]',
#   'ii[no5]',
#   'ii7[no5]',
#   'ii7[no5][no1]',
#   'ii9[no5]',
#   'ii9[no3]',
#   'biii[no5]',
#   'biii7[no5]',
#   'biii7[no5][no1]',
#   'biii9[no5]',
#   'biii9[no3]',
#   'iii[no5]',
#   'iii7[no5]',
#   'iii7[no5][no1]',
#   'iii9[no5]',
#   'iii9[no3]',
#   'iv[no5]',
#   'iv7[no5]',
#   'iv7[no5][no1]',
#   'iv9[no5]',
#   'iv9[no3]',
#   'v[no5]',
#   'v7[no5]',
#   'v7[no5][no1]',
#   'v9[no5]',
#   'v9[no3]',
#   'vi[no5]',
#   'vi7[no5]',
#   'vi7[no5][no1]',
#   'vi9[no5]',
#   'vi9[no3]',
#   'vii[no5]',
#   'vii7[no5]',
#   'vii7[no5][no1]',
#   'vii9[no5]',
#   'vii9[no3]',
#   'III[no5]',
#   'III7[no5]',
#   'III7[no5][no1]',
#   'III9[no5]',
#   'III9[no3]',
#   'V[no5]',
#   'V7[no5]',
#   'V7[no5][no1]',
#   'V9[no5]',
#   'V9[no3]',
#   'I#7[no#3]',
#   'bII#7[no#3]',
#   'II#7[no#3]',
#   'bIII#7[no#3]',
#   'III#7[no#3]',
#   'IV#7[no#3]',
#   'V#7[no#3]',
#   'VI#7[no#3]',
#   'bVI#7[no#3]',
#   'bVII#7[no#3]',
#   'VII#7[no#3]',
#   'ivb7[no3]',
#   'I+',
#   'bII+',
#   'II+',
#   'bIII+',
#   'III+',
#   'IV+',
#   'V+',
#   'VI+',
#   'bVI+',
#   'bVII+',
#   'VII+',
#   'I+532',
#   'I+7',
#   'I+b7',
#   'I+#7',
#   'I+743',
#   'I+7#43',
#   'bII+532',
#   'bII+7',
#   'bII+b7',
#   'bII+#7',
#   'bII+743',
#   'bII+7#43',
#   'II+532',
#   'II+7',
#   'II+b7',
#   'II+#7',
#   'II+743',
#   'II+7#43',
#   'bIII+532',
#   'bIII+7',
#   'bIII+b7',
#   'bIII+#7',
#   'bIII+743',
#   'bIII+7#43',
#   'III+532',
#   'III+7',
#   'III+b7',
#   'III+#7',
#   'III+743',
#   'III+7#43',
#   'IV+532',
#   'IV+7',
#   'IV+b7',
#   'IV+#7',
#   'IV+743',
#   'IV+7#43',
#   'V+532',
#   'V+7',
#   'V+b7',
#   'V+#7',
#   'V+743',
#   'V+7#43',
#   'VI+532',
#   'VI+7',
#   'VI+b7',
#   'VI+#7',
#   'VI+743',
#   'VI+7#43',
#   'bVI+532',
#   'bVI+7',
#   'bVI+b7',
#   'bVI+#7',
#   'bVI+743',
#   'bVI+7#43',
#   'bVII+532',
#   'bVII+7',
#   'bVII+b7',
#   'bVII+#7',
#   'bVII+743',
#   'bVII+7#43',
#   'VII+532',
#   'VII+7',
#   'VII+b7',
#   'VII+#7',
#   'VII+743',
#   'VII+7#43',
#   'viio532',
#   'I[no3]',
#   'I543',
#   'IV543',
#   'V9[no5][no3]',
#   'I732'],
#  array([['O(0,0,0)', 'O(2,2,2)', 'O(-2,0,-1)', ..., 'O(0,2,2,-1)',
#          'O(-3,2,0)', 'O(0,-1,-3,-1)'],
#         ['O(-2,-2,-2)', 'O(0,0,0)', 'O(1,1,1)', ..., 'O(2,-2,0,0)',
#          'O(3,2,0)', 'O(0,-1,2,-2)'],
#         ['O(0,1,2)', 'O(-1,-1,-1)', 'O(0,0,0)', ..., 'O(1,-3,-1,-1)',
#          'O(2,1,-1)', 'O(2,-1,-2,1)'],
#         ...,
#         ['O(-2,-2,1,0)', 'O(0,0,-2,2)', 'O(1,1,-1,3)', ..., 'O(0,0,0,0)',
#          'O(0,-2,-2,-3)', 'O(-1,2,1,2)'],
#         ['O(-2,0,3)', 'O(-3,-2,0)', 'O(-2,-1,1)', ..., 'O(3,0,2,2)',
#          'O(0,0,0)', 'O(3,-3,-3,2)'],
#         ['O(1,0,1,3)', 'O(-2,2,0,1)', 'O(-1,-2,1,2)', ...,
#          'O(-2,-1,-2,1)', 'O(-2,-3,3,3)', 'O(0,0,0,0)']], dtype='<U16'))

# %%
bachChorale = m21.corpus.parse('bwv66.6').corpusFilepath
seq,chords = readScore(bachChorale,music21=True,show=True)

# %%
# To write chords and corresponding operators - uses musescore
WRITEscoreOps(seq,w=True)

# %%
dnodes,dedges,dcounts,deg,modul,Gx,Gxu = scoreNetwork(seq,ntx=True,general=True)
print('average degree = ',deg,' modularity = ',modul)
# Write to csv for visualization in Gephi or other network drawing software (see figure below)
# dnodes.to_csv('nodesbwv66.csv')
# dedges.to_csv('edgesbwv66.csv')
# Get modularity scores
part = cm.best_partition(Gxu)
# Out:
# average degree =  1.7083333333333333  modularity =  0.45844875346260383

# %% [markdown]
# ## ![title](bwv66.png)

# %%
dn = np.array(dnodes)
labe = []
modu = []
modul = []
for m in range(len(dn)):
    labe.append(str(dn[m][0]))
    modu.append(part[str(m)])
    modul.append([str(dn[m][0]),Gx.degree()[str(m)],part[str(m)]])
modul = pd.DataFrame(modul,columns=['Label','Degree','Modularity'])
moduldict = dict(zip(labe,modu))

# %%
modul[['Label','Degree','Modularity']].query('Modularity == 0').sort_values(by=['Degree'],ascending=False)
# Out:
#      Label  Degree  Modularity
# 14    EG#B       8           0
# 1     AC#E       5           0
# 11    DF#A       4           0
# 17     F#B       2           0
# 18   F#G#B       2           0
# 21  G#BC#E       2           0
# 23   G#BDE       2           0

# %%
# Dictionary of modularity classes and relative keys
keydict = {0:'A', 1:'f#', 2:'A', 3:'B'}

# %%
# Determination of operators
try:
    ntot = seq.shape[0]
except:
    ntot = len(seq)
ops = []
for i in range(ntot):
    if i < ntot-1: 
        ops.append(generalizedOpsName(seq[i],seq[i+1])[1])

# %%
# Score analysis
# First chord
rn = []
ch = np.copy(seq[0])
for n in range(1,len(ch)):
    if ch[n] < ch[n-1]: ch[n] += 12
ch += 60
n = m21.chord.Chord(ch.tolist())
chord = ''.join(n.pitchNames)
key = keydict[moduldict[chord]] 
rn.append(m21.roman.romanNumeralFromChord(n, m21.key.Key(key)).figure)
# Full score
nx = ntot-1
for i in range(nx):
    try:
        # these are the modulations
        if i == 8000:
            rn.append('')
        elif i == 10000:
            continue
        else:
            idx,idy = np.where(tab == ops[i])
            tmp = []
            for n in range(len(idy)):
                if (rn[i] == str(head[idx[n]])):
                    tmp.append(head[idy[n]])
            if len(tmp) == 1:
                rn.append(tmp[0])
            else:
                chord = ''.join(m21.chord.Chord(PCSet(seq[i]).normalOrder().tolist()).pitchNames)
                key = keydict[moduldict[chord]]
                for n in range(len(tmp)):
                    ch = m21.roman.RomanNumeral(tmp[n],m21.key.Key(key)).pitchClasses
                    if PCSet(ch).normalOrder().tolist() == seq[i+1]:
                        rn.append(str(tmp[n]))
                        break
    except:
        print('check at or before chord no. ',i,' for possible modulation')
        print(rn[i-1],ops[i-1])
        nx = i
        break

# %%
# Score analysis
# First chord
rn = []
ch = np.copy(seq[0])
for n in range(1,len(ch)):
    if ch[n] < ch[n-1]: ch[n] += 12
ch += 60
n = m21.chord.Chord(ch.tolist())
chord = ''.join(n.pitchNames)
key = keydict[moduldict[chord]] 
rn.append(m21.roman.romanNumeralFromChord(n, m21.key.Key(key)).figure)
# Full score
nx = ntot-1
i = 0
while i < nx:   
    try:
        idx,idy = np.where(tab == ops[i])
        tmp = []
        for n in range(len(idy)):
            if (rn[i] == str(head[idx[n]])):
                tmp.append(head[idy[n]])
        if len(tmp) == 1:
            rn.append(tmp[0])
        else:
            chord = ''.join(m21.chord.Chord(PCSet(seq[i]).normalOrder().tolist()).pitchNames)
            key = keydict[moduldict[chord]]
            for n in range(len(tmp)):
                ch = m21.roman.RomanNumeral(tmp[n],m21.key.Key(key)).pitchClasses
                if PCSet(ch).normalOrder().tolist() == seq[i+1]:
                    rn.append(str(tmp[n]))
                    break
        i += 1
    except:
        try:
            print('possible modulation at or before chord no. ',i)
            rn.pop()
            ch = np.copy(PCSet(seq[i-1]).normalOrder().tolist())
            for n in range(1,len(ch)):
                if ch[n] < ch[n-1]: ch[n] += 12
            ch += 60
            n = m21.chord.Chord(ch.tolist())
            chord = ''.join(n.pitchNames)
            key = keydict[moduldict[chord]] 
            rn.append(m21.roman.romanNumeralFromChord(n, m21.key.Key(key)).figure)
            i -= 1
        except:
            print('PROBLEM')
            break
# Out:
# possible modulation at or before chord no.  35
# possible modulation at or before chord no.  41

# %%
# Create dictionary of score analysis
reference = []
for n in range(nx):
    chord = ''.join(m21.chord.Chord(PCSet(seq[n]).normalOrder().tolist()).pitchNames)
    entry = [PCSet(seq[n]).normalOrder(),chord,rn[n],ops[n],keydict[moduldict[chord]]]
    reference.append(entry)

# %%
# Add last chord
ops.append(' ')
chord = ''.join(m21.chord.Chord(PCSet(seq[nx]).normalOrder().tolist()).pitchNames)
entry = [PCSet(seq[nx]).normalOrder(),chord,rn[nx],ops[nx],keydict[moduldict[chord]]]
reference.append(entry)

# %%
# Set dictionary as pandas dataframe
analysis = pd.DataFrame(reference,columns=['pcs','chord','rn','ops','key'])

# %%
analysis
# Out:
#               pcs     chord              rn            ops key
# 0       [9, 1, 4]      AC#E               I     O(-1,-2,0)   A
# 1      [4, 8, 11]      EG#B               V       O(2,1,2)   A
# 2       [6, 9, 1]     F#AC#              vi    O(-2,-1,-2)  f#
# 3      [4, 8, 11]      EG#B               V       O(0,1,2)   A
# 4       [9, 1, 4]      AC#E               I     O(-1,-2,0)   A
# 5      [4, 8, 11]      EG#B               V       O(0,1,2)   A
# 6       [9, 1, 4]      AC#E               I       O(0,0,0)   A
# 7       [9, 1, 4]      AC#E               I     O(-1,-2,0)   A
# 8      [4, 8, 11]      EG#B               V    O(0,0,0,-2)   A
# 9   [8, 11, 2, 4]     G#BDE              V7   O(1,-2,-1,0)   A
# 10      [9, 1, 4]      AC#E               I      O(-1,0,1)   A
# 11      [1, 5, 8]    C#E#G#             III       O(0,1,1)  f#
# 12      [6, 9, 1]     F#AC#              vi       O(2,2,1)  f#
# 13     [8, 11, 2]      G#BD            viio       O(0,2,3)  f#
# 14      [1, 5, 8]    C#E#G#             III    O(0,0,0,-2)  f#
# 15  [5, 8, 11, 1]   FA-C-D-            III7    O(1,1,-2,0)  f#
# 16      [6, 9, 1]     F#AC#              vi       O(0,0,0)  f#
# 17      [6, 9, 1]     F#AC#              vi     O(0,-1,-2)  f#
# 18     [6, 8, 11]     F#G#B       vii7[no5]      O(0,-2,0)   A
# 19        [6, 11]       F#B  vii7[no5][no1]      O(2,0,-2)   A
# 20     [4, 8, 11]      EG#B               V       O(0,1,0)   A
# 21     [9, 11, 4]       ABE             i52     O(-3,0,-1)   A
# 22     [11, 3, 6]     BD#F#              II    O(0,0,0,-2)   A
# 23  [3, 6, 9, 11]    E-F#AB             II7   O(1,-2,-1,2)   A
# 24      [1, 4, 8]     C#EG#             iii       O(0,2,1)   A
# 25      [6, 9, 1]     F#AC#              vi       O(0,0,1)  f#
# 26      [2, 6, 9]      DF#A              IV  O(2,-1,-2,-1)   A
# 27  [8, 11, 1, 4]    G#BC#E            iii7    O(0,0,-2,0)   A
# 28     [4, 8, 11]      EG#B               V       O(0,1,2)   A
# 29      [9, 1, 4]      AC#E               I       O(0,0,0)   A
# 30      [9, 1, 4]      AC#E               I       O(0,1,2)   A
# 31      [2, 6, 9]      DF#A              IV       O(0,0,2)   A
# 32     [11, 2, 6]      BDF#              ii    O(-3,-1,-1)   B
# 33      [1, 5, 8]    C#E#G#             III       O(0,1,1)  f#
# 34      [6, 9, 1]     F#AC#               i    O(2,1,0,-1)  f#
# 35  [6, 8, 11, 2]    F#G#BD           ii/o7   O(-1,0,2,-1)  f#
# 36      [1, 5, 8]    C#E#G#               V     O(0,-3,-2)  f#
# 37      [1, 2, 6]     C#DF#     bVI#7[no#3]      O(-2,0,0)   B
# 38     [11, 2, 6]      BDF#              iv    O(-3,-1,-1)   B
# 39      [1, 5, 8]    C#E#G#               V       O(0,1,2)  f#
# 40     [6, 10, 1]    F#A#C#               V       O(0,0,1)   B
# 41     [2, 6, 10]     DF#A#           bIII+    O(2,0,0,-1)   B
# 42  [10, 1, 4, 6]  B-D-F-G-              V7     O(1,0,0,0)   B
# 43  [11, 1, 4, 6]    BC#EF#           ii743    O(0,0,-2,0)   B
# 44  [11, 1, 2, 6]    BC#DF#            i532   O(-1,0,-1,0)   B
# 45     [6, 10, 1]    F#A#C#               V       O(0,1,1)   B
# 46     [11, 2, 6]      BDF#               i    O(0,0,0,-1)   B
# 47  [11, 1, 2, 6]    BC#DF#            i532     O(0,1,0,0)   B
# 48     [11, 2, 6]      BDF#               i      O(0,0,-1)   B
# 49     [11, 2, 5]       BDF              io     O(-1,-1,1)   B
# 50     [6, 10, 1]    F#A#C#               V                  B

# %%
# display the analyzed score
l = 0
analyzed = copy.deepcopy(chords)
for c in analyzed.recurse().getElementsByClass('Chord'):
    c.closedPosition(forceOctave=4,inPlace=True)
    c.addLyric('')
    c.addLyric('')
#     c.addLyric(str(ops[l]))
    c.addLyric(str(rn[l]))
    l += 1
analyzed.show()
