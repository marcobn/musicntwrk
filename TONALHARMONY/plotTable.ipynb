# %%
import sys, pickle
import numpy as np
from pcsPy import *
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
# Out:
# <div id="glowscript" class="glowscript"></div>

# %%
# Display width settings
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
colormap = cm.get_cmap('tab10', 256)
newcolors = colormap(np.linspace(0, 1, 256))
black = np.array([0/256, 0/256, 0/256, 1])
newcolors[:26, :] = black
newcmp = ListedColormap(newcolors)

# %%
f = open('tonal.harmony.minimal','rb')
head = pickle.load(f)
table = pickle.load(f)
f.close()

# %%
t = np.array(table).T

tp = t.tolist()
tp.insert(0,head)

t = np.array(tp).T
table = t.tolist()

head.insert(0,'')

# %%
idx = len(head)
print(idx)
# Out:
# 281

# %%
h = np.array(head)
idx = np.argwhere(h == 'VII7#43')[0][0]
print(idx)
# Out:
# 167

# %%
f = open('Pnumber.LvB','rb')
Pnumber = pickle.load(f)
f.close()
plotHarmonicTable(head[:idx],table[:idx][:idx],Pnumber,height=42,width=54,colmap=newcmp,label=False,star=x)

# %%
f = open('Pnumber.JSB','rb')
Pnumber = pickle.load(f)
f.close()
plotHarmonicTable(head[:idx],table[:idx][:idx],Pnumber,height=42,width=54,colmap=newcmp,label=False,star='x')
